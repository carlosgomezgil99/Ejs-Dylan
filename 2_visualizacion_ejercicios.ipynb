# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)
#
# # Visualización de datos - Ejercicios
#
# A lo largo de este tutorial, utilizará un conjunto de datos del mercado de valores norteamericano de 29 empresas de 2006 a 2017. Se nos pide:
#
# 1. Preparar los datasets para crear visualizaciones
# 2. Graficar la siguiente información:
#     - Precio de cierre de AAPL, JPM, GOOGL y AMZN para todo el período de estudio.
#     - Precio máximo de AAPL en 2014, 2015, 2016 y 2017.
#     - Distribución del volumen de transacciones por empresa para todo el período. Sólo incluir AAPL, JPM, GOOGL y AMZN.
#     - Volumen de transacciones anual de AAPL, JPM, GOOGL y AMAZN. En el mismo gráfico debo poder comparar el volumen por año y la proporción de este que corresponde a cada empresa.
#     - Relación entre los retornos diarios (`Open` - `Close` / `Open`) de las acciones de GOOGL y AMZN durante todo el período de estudio.
#
#
# ## Diccionario de datos
#
# El dataset tiene las siguientes columnas:
#
# - **Date:** fecha correspondiente al valor observado
# - **Open:** Precio (en USD) al mercado abierto en la fecha especificada
# - **High:** precio más alto (en USD) alcanzado durante la fecha correspondiente
# - **Low:** precio más bajo (en USD) alcanzado durante la fecha correspondiente
# - **Close:** Precio (en USD) al cierre del mercado en la fecha especificada
# - **Volumen:** número de acciones negociadas
# - **Name:** Símbolo bursátil de la empresa.

# %% [markdown]
# ## Importar librerías y leer datos

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio

import pandas as pd

url = "https://raw.githubusercontent.com/szrlee/Stock-Time-Series-Analysis/master/data/all_stocks_2006-01-01_to_2018-01-01.csv"
df = pd.read_csv(url)

# %% [markdown]
# ## Revisiones generales

# %%
df
# Out:
#              Date   Open   High    Low  Close    Volume  Name
# 0      2006-01-03  77.76  79.35  77.24  79.11   3117200   MMM
# 1      2006-01-04  79.49  79.49  78.25  78.71   2558000   MMM
# 2      2006-01-05  78.41  78.65  77.56  77.99   2529500   MMM
# 3      2006-01-06  78.64  78.90  77.64  78.63   2479500   MMM
# 4      2006-01-09  78.50  79.83  78.46  79.02   1845600   MMM
# ...           ...    ...    ...    ...    ...       ...   ...
# 93607  2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 93608  2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 93609  2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 93610  2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 93611  2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [93612 rows x 7 columns]

# %%
df.Date.isnull().sum()
# Out:
# 0

# %%
df.Open.isnull().sum()
# Out:
# 25

# %%
df[df.Open.isnull()]
# Out:
#              Date  Open    High     Low   Close    Volume Name
# 2913   2017-07-31   NaN  201.66     NaN  201.17   1833625  MMM
# 5933   2017-07-31   NaN   85.70     NaN   85.23   3079797  AXP
# 11972  2017-07-31   NaN     NaN     NaN  242.46   5777271   BA
# 14992  2017-07-31   NaN     NaN     NaN  113.95   4486013  CAT
# 18012  2017-07-31   NaN  110.00     NaN  109.19   7561205  CVX
# 24051  2017-07-31   NaN     NaN   45.79   45.84  13622891   KO
# 25815  2012-08-01   NaN     NaN     NaN   49.14         0  DIS
# 27071  2017-07-31   NaN  110.14     NaN  109.93   6815349  DIS
# 30091  2017-07-31   NaN   80.39     NaN   80.04  12820175  XOM
# 33111  2017-07-31   NaN   25.69     NaN   25.61  30616287   GE
# 36131  2017-07-31   NaN  225.50     NaN  225.33   1999637   GS
# 39151  2017-07-31   NaN  149.98     NaN  149.60   5253318   HD
# 42171  2017-07-31   NaN  144.93     NaN  144.67   4355718  IBM
# 48210  2017-07-31   NaN  133.58     NaN  132.72   5440788  JNJ
# 51230  2017-07-31   NaN   92.36     NaN   91.80  11520329  JPM
# 54250  2017-07-31   NaN     NaN  154.85  155.14   4280364  MCD
# 57269  2017-07-31   NaN     NaN   63.51   63.88  11714888  MRK
# 63308  2017-07-31   NaN   59.12   58.33   59.05   6225907  NKE
# 66328  2017-07-31   NaN     NaN     NaN   33.16  21982573  PFE
# 69348  2017-07-31   NaN   91.07     NaN   90.82   7835661   PG
# 72368  2017-07-31   NaN     NaN     NaN  128.09   1077258  TRV
# 75388  2017-07-31   NaN  119.34  118.44  118.57   2172327  UTX
# 78408  2017-07-31   NaN     NaN     NaN  191.81   3776476  UNH
# 81428  2017-07-31   NaN   48.57     NaN   48.40  28456827   VZ
# 84448  2017-07-31   NaN     NaN     NaN   79.99   6263189  WMT

# %%
df.drop(df[df.Open.isnull()].index,inplace=True)

# %%
df.Close.isnull().sum()
# Out:
# 0

# %%
df.Low.isnull().sum()
# Out:
# 0

# %%
df.High.isnull().sum()
# Out:
# 0

# %%
df.Name.isnull().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# Name       object
# dtype: object

# %%
df.Date=pd.to_datetime(df.Date,format='%Y-%m-%d')

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume             int64
# Name              object
# dtype: object

# %%
df.describe(include='all')
# Out:
# C:\Users\carlo\AppData\Local\Temp/ipykernel_23512/2884002236.py:1: FutureWarning:
#
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#                        Date          Open          High           Low  \
# count                 93587  93587.000000  93587.000000  93587.000000
# unique                 3020           NaN           NaN           NaN
# top     2006-01-03 00:00:00           NaN           NaN           NaN
# freq                     31           NaN           NaN           NaN
# first   2006-01-03 00:00:00           NaN           NaN           NaN
# last    2017-12-29 00:00:00           NaN           NaN           NaN
# mean                    NaN     85.623260     86.382961     84.836485
# std                     NaN    108.151723    108.962620    107.227791
# min                     NaN      6.750000      7.170000      0.000000
# 25%                     NaN     33.950000     34.290000     33.600000
# 50%                     NaN     60.040000     60.620000     59.490000
# 75%                     NaN     94.000000     94.740000     93.250000
# max                     NaN   1204.880000   1213.410000   1191.150000
#
#                Close        Volume   Name
# count   93587.000000  9.358700e+04  93587
# unique           NaN           NaN     31
# top              NaN           NaN    MMM
# freq             NaN           NaN   3019
# first            NaN           NaN    NaN
# last             NaN           NaN    NaN
# mean       85.634973  2.015982e+07    NaN
# std       108.130598  3.442490e+07    NaN
# min         6.660000  8.708300e+04    NaN
# 25%        33.950000  5.040876e+06    NaN
# 50%        60.040000  9.702410e+06    NaN
# 75%        94.000000  2.075386e+07    NaN
# max      1195.830000  8.432640e+08    NaN

# %% [markdown]
# ## Precio de cierre de AAPL, JPM, GOOGL y AMZN para todo el período de estudio

# %%
filtro=df.Name.isin(['AAPL','JPM','GOOGL','AMZN'])  
df_close=df.loc[filtro,['Date','Close','Name']]

# %%
pio.templates.default='simple_white'
fig=px.line(data_frame=df_close,x='Date',y='Close',color='Name',title='Precio del cierre máximo diario de Apple, JP Morgan, Google y Amazon')
fig.show()

# %% [markdown]
# ## Precio máximo de AAPL en 2014, 2015, 2016 y 2017

# %%
filtro_AAPL=df.Name=='AAPL'
filtro_years=df.Date.dt.year.isin([2014,2015,2016,2017])
df_AAPL=df.loc[filtro_AAPL & filtro_years,['Date','High','Name']].groupby(df.Date.dt.year)['High'].max().reset_index()
df_AAPL
# Out:
#    Date    High
# 0  2014  119.75
# 1  2015  134.54
# 2  2016  118.69
# 3  2017  177.20

# %%
fig=px.bar(data_frame=df_AAPL,x='Date',y='High',title='Precio máximo anual de Apple de 2014 a 2017')
fig.show()

# %% [markdown]
# ## Distribución del volumen total de transacciones por empresa para todo el período. Sólo incluir AAPL, JPM, GOOGL y AMZN

# %%
df_volumen=df.loc[filtro,['Date','Volume','Name']].groupby('Name')['Volume'].sum().reset_index()

# %%
df_volumen.head()
# Out:
#     Name        Volume
# 0   AAPL  395928831057
# 1   AMZN   17907839742
# 2  GOOGL   10721989174
# 3    JPM   85363207655

# %%
pio.templates.default='presentation'
fig=px.pie(data_frame=df_volumen,hole=0.5,values='Volume',names='Name',title='Distribución del volumen total de Apple, Amazon,Google y JP Morgan')
fig.show()

# %% [markdown]
# ## Volumen de transacciones anual de AAPL, JPM, GOOGL y AMAZN. En el mismo gráfico debo poder comparar el volumen por año y la proporción de este correspondiente a cada empresa.

# %%
df_volumen_anual=df.loc[filtro,['Date','Volume','Name']].groupby([df.Date.dt.year,'Name'])['Volume'].sum().reset_index()
df_volumen_anual
# Out:
#     Date   Name       Volume
# 0   2006   AAPL  53982792080
# 1   2006   AMZN   1792552278
# 2   2006  GOOGL   2134134420
# 3   2006    JPM   2710492500
# 4   2007   AAPL  61849550357
# 5   2007   AMZN   2454647696
# 6   2007  GOOGL   1367346735
# 7   2007    JPM   4755970035
# 8   2008   AAPL  71532125609
# 9   2008   AMZN   2520431923
# 10  2008  GOOGL   1606159196
# 11  2008    JPM  12400758806
# 12  2009   AAPL  35850854893
# 13  2009   AMZN   2146562394
# 14  2009  GOOGL    885224033
# 15  2009    JPM  16071080671
# 16  2010   AAPL  37612777363
# 17  2010   AMZN   1829323102
# 18  2010  GOOGL    799731223
# 19  2010    JPM  10371639245
# 20  2011   AAPL  31108767508
# 21  2011   AMZN   1464295930
# 22  2011  GOOGL    777725691
# 23  2011    JPM   9716772550
# 24  2012   AAPL  32994076346
# 25  2012   AMZN   1050233531
# 26  2012  GOOGL    649998834
# 27  2012    JPM   8267915072
# 28  2013   AAPL  25606397999
# 29  2013   AMZN    748378451
# 30  2013  GOOGL    526336666
# 31  2013    JPM   5324287797
# 32  2014   AAPL  15934492690
# 33  2014   AMZN   1030226257
# 34  2014  GOOGL    529858529
# 35  2014    JPM   3985797974
# 36  2015   AAPL  13019939940
# 37  2015   AMZN    954245799
# 38  2015  GOOGL    545842483
# 39  2015    JPM   3992625707
# 40  2016   AAPL   9625820389
# 41  2016   AMZN   1034016481
# 42  2016  GOOGL    493769102
# 43  2016    JPM   4289325011
# 44  2017   AAPL   6811235883
# 45  2017   AMZN    882925900
# 46  2017  GOOGL    405862262
# 47  2017    JPM   3476542287

# %%
fig=px.bar(data_frame=df_volumen_anual,x='Date',y='Volume',color='Name')
fig.show()

# %% [markdown]
# ## Relación entre los retornos diarios (`Open` - `Close` / `Open`) de las acciones de GOOGL y AMZN durante todo el período de estudio

# %%
filtro_comp=df.Name.isin(['GOOGL','AMZN'])
df_retornos=df.loc[filtro_comp,['Date','Open','Close','Name']]
df_retornos['retornos']=(df_retornos.Open-df_retornos.Close)/df_retornos.Open

# %%
df_retornos
# Out:
#             Date     Open    Close   Name  retornos
# 84555 2006-01-03   211.47   217.83  GOOGL -0.030075
# 84556 2006-01-04   222.17   222.84  GOOGL -0.003016
# 84557 2006-01-05   223.22   225.85  GOOGL -0.011782
# 84558 2006-01-06   228.66   233.06  GOOGL -0.019243
# 84559 2006-01-09   233.44   233.68  GOOGL -0.001028
# ...          ...      ...      ...    ...       ...
# 90588 2017-12-22  1172.08  1168.36   AMZN  0.003174
# 90589 2017-12-26  1168.36  1176.76   AMZN -0.007190
# 90590 2017-12-27  1179.91  1182.26   AMZN -0.001992
# 90591 2017-12-28  1189.00  1186.10   AMZN  0.002439
# 90592 2017-12-29  1182.35  1169.47   AMZN  0.010894
#
# [6038 rows x 5 columns]

# %%
fig=px.bar(data_frame=df_retornos,x='Date',y='retornos',color='Name',title='Retornos diarios de las acciones de Google y Apple')
fig.show()
